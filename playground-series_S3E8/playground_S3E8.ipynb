# %% [markdown]
# <a href="https://colab.research.google.com/github/iamVaibhav100/kaggle/blob/main/playground-series_S3E8/playground_S3E8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
X = pd.read_csv("sample_data/train.csv")
X.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df = pd.read_csv("sample_data/cubic_zirconia.csv")
df.head()
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779

# %%
X.shape, df.shape
# Out:
# ((193573, 11), (26967, 11))

# %%
X = pd.concat([X, df])
X.shape
# Out:
# (220540, 12)

# %%
X.head()
# Out:
#     id  carat        cut color clarity  depth  table     x     y     z  price  \
# 0  0.0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1  1.0   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2  2.0   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3  3.0   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4  4.0   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
#
#    Unnamed: 0
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
X = X.iloc[:, :-1]
X.head()
# Out:
#     id  carat        cut color clarity  depth  table     x     y     z  price
# 0  0.0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1  1.0   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2  2.0   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3  3.0   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4  4.0   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
X.shape
# Out:
# (220540, 11)

# %%
X = X.dropna()

# %%
X.shape
# Out:
# (193573, 11)

# %%
drop_columns = ["id", "price"]
y = X["price"]
X = X.drop(drop_columns, axis=1)

# %%
y.head(5)
# Out:
# 0    13619
# 1    13387
# 2     2772
# 3      666
# 4    14453
# Name: price, dtype: int64

# %%
y.shape
# Out:
# (193573,)

# %%
X["Volume"] = X['x'] * X['y'] * X['z']
X.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z      Volume
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  242.465405
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  330.508360
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50  114.112950
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71   52.345818
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  277.692705

# %%
X["depth-table-ratio"] = X['depth'] / X['table']
X.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z      Volume  \
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  242.465405
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  330.508360
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50  114.112950
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71   52.345818
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  277.692705
#
#    depth-table-ratio
# 0           1.072414
# 1           1.068966
# 2           1.073684
# 3           1.100000
# 4           1.061017

# %%
corr_matrix = X.corr()
corr_matrix["Volume"]
# Out:
# carat                0.998611
# depth                0.015253
# table                0.217641
# x                    0.980727
# y                    0.980397
# z                    0.976710
# Volume               1.000000
# depth-table-ratio   -0.172704
# Name: Volume, dtype: float64

# %%
X = X.drop(['x', 'y', 'z'], axis=1)
X.head()
# Out:
#    carat        cut color clarity  depth  table      Volume  depth-table-ratio
# 0   1.52    Premium     F     VS2   62.2   58.0  242.465405           1.072414
# 1   2.03  Very Good     J     SI2   62.0   58.0  330.508360           1.068966
# 2   0.70      Ideal     G     VS1   61.2   57.0  114.112950           1.073684
# 3   0.32      Ideal     G     VS1   61.6   56.0   52.345818           1.100000
# 4   1.70    Premium     G     VS2   62.6   59.0  277.692705           1.061017

# %%
cut_mapping = {'Fair': 1, 'Good': 2, 'Very Good': 3, 'Premium': 4, 'Ideal': 5}
color_mapping = {'J': 1, 'I': 2, 'H': 3, 'G': 4, 'F': 5, 'E': 6, 'D': 7}
clarity_mapping = {'I3': 1, 'I2': 2, 'I1': 3, 'SI2': 4, 'SI1': 5, 'VS2': 6, 'VS1': 7, 'VVS2': 8, 'VVS1': 9, 'IF': 10, 'FL': 11}

X['cut'] = X['cut'].map(cut_mapping)
X['color'] = X['color'].map(color_mapping)
X['clarity'] = X['clarity'].map(clarity_mapping)

# %%
X.head()
# Out:
#    carat  cut  color  clarity  depth  table      Volume  depth-table-ratio
# 0   1.52    4      5        6   62.2   58.0  242.465405           1.072414
# 1   2.03    3      1        4   62.0   58.0  330.508360           1.068966
# 2   0.70    5      4        7   61.2   57.0  114.112950           1.073684
# 3   0.32    5      4        7   61.6   56.0   52.345818           1.100000
# 4   1.70    4      4        6   62.6   59.0  277.692705           1.061017

# %%
corr_matrix = X.corr()
corr_matrix["depth-table-ratio"]
# Out:
# carat               -0.173935
# cut                  0.279530
# color                0.013270
# clarity              0.124265
# depth                0.608895
# table               -0.910854
# Volume              -0.172704
# depth-table-ratio    1.000000
# Name: depth-table-ratio, dtype: float64

# %%
X.shape
# Out:
# (193573, 8)

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=1)

# %%
X_train
# Out:
#         carat  cut  color  clarity  depth  table      Volume  \
# 159000   2.07    4      2        5   62.5   57.0  331.570668
# 175733   1.21    3      4        4   62.0   56.0  198.367128
# 94531    1.51    4      4        5   61.2   60.0  243.214320
# 98277    1.06    5      7        5   60.7   55.0  173.973600
# 120576   0.34    5      2        5   61.8   57.0   56.623050
# ...       ...  ...    ...      ...    ...    ...         ...
# 73349    0.41    3      7        7   62.8   57.0   66.447216
# 109259   0.40    5      5        9   61.9   55.0   66.054450
# 50057    0.38    5      5        9   62.2   56.0   62.622832
# 5192     0.72    5      5        6   62.0   54.8  117.497088
# 128037   0.33    5      4        6   62.3   54.0   51.586976
#
#         depth-table-ratio
# 159000           1.096491
# 175733           1.107143
# 94531            1.020000
# 98277            1.103636
# 120576           1.084211
# ...                   ...
# 73349            1.101754
# ...

# %%
from xgboost import XGBRegressor

model = XGBRegressor(n_estimators=500, learning_rate=0.05, random_state=1)

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=1, ...)

# %%
from sklearn.metrics import mean_absolute_error

valid_preds = model.predict(X_valid)
mae = mean_absolute_error(valid_preds, y_valid)

# %%
mae
# Out:
# 294.70222251746

# %%
X_test = pd.read_csv("sample_data/test.csv")
X_test.head()
# Out:
#        id  carat        cut color clarity  depth  table     x     y     z
# 0  193573   0.35      Ideal     D     VS2   62.3   56.0  4.51  4.54  2.82
# 1  193574   0.77  Very Good     F     SI2   62.8   56.0  5.83  5.87  3.68
# 2  193575   0.71      Ideal     I     VS2   61.9   53.0  5.77  5.74  3.55
# 3  193576   0.33      Ideal     G    VVS2   61.6   55.0  4.44  4.42  2.73
# 4  193577   1.20  Very Good     I     VS2   62.7   56.0  6.75  6.79  4.24

# %%
cut_mapping = {'Fair': 1, 'Good': 2, 'Very Good': 3, 'Premium': 4, 'Ideal': 5}
color_mapping = {'J': 1, 'I': 2, 'H': 3, 'G': 4, 'F': 5, 'E': 6, 'D': 7}
clarity_mapping = {'I3': 1, 'I2': 2, 'I1': 3, 'SI2': 4, 'SI1': 5, 'VS2': 6, 'VS1': 7, 'VVS2': 8, 'VVS1': 9, 'IF': 10, 'FL': 11}

X_test['cut'] = X_test['cut'].map(cut_mapping)
X_test['color'] = X_test['color'].map(color_mapping)
X_test['clarity'] = X_test['clarity'].map(clarity_mapping)

# %%
X_test.head()
# Out:
#        id  carat  cut  color  clarity  depth  table     x     y     z
# 0  193573   0.35    5      7        6   62.3   56.0  4.51  4.54  2.82
# 1  193574   0.77    3      5        4   62.8   56.0  5.83  5.87  3.68
# 2  193575   0.71    5      2        6   61.9   53.0  5.77  5.74  3.55
# 3  193576   0.33    5      4        8   61.6   55.0  4.44  4.42  2.73
# 4  193577   1.20    3      2        6   62.7   56.0  6.75  6.79  4.24

# %%
X_test['Volume'] = X_test['x'] * X_test['y'] * X_test['z']
X_test['depth-table-ratio'] = X_test['depth'] / X_test['table']
X_test.head()
# Out:
#        id  carat  cut  color  clarity  depth  table     x     y     z  \
# 0  193573   0.35    5      7        6   62.3   56.0  4.51  4.54  2.82
# 1  193574   0.77    3      5        4   62.8   56.0  5.83  5.87  3.68
# 2  193575   0.71    5      2        6   61.9   53.0  5.77  5.74  3.55
# 3  193576   0.33    5      4        8   61.6   55.0  4.44  4.42  2.73
# 4  193577   1.20    3      2        6   62.7   56.0  6.75  6.79  4.24
#
#        Volume  depth-table-ratio
# 0   57.740628           1.112500
# 1  125.937328           1.121429
# 2  117.575290           1.167925
# 3   53.575704           1.120000
# 4  194.329800           1.119643

# %%
ids = X_test["id"]
X_test = X_test.drop(['id', 'x', 'y', 'z'], axis=1)
X_test.head()
# Out:
#    carat  cut  color  clarity  depth  table      Volume  depth-table-ratio
# 0   0.35    5      7        6   62.3   56.0   57.740628           1.112500
# 1   0.77    3      5        4   62.8   56.0  125.937328           1.121429
# 2   0.71    5      2        6   61.9   53.0  117.575290           1.167925
# 3   0.33    5      4        8   61.6   55.0   53.575704           1.120000
# 4   1.20    3      2        6   62.7   56.0  194.329800           1.119643

# %%
X_test.shape
# Out:
# (129050, 8)

# %%
preds = model.predict(X_test)

# %%
output = pd.DataFrame({
    "id": ids,
    "price": preds
})
output
# Out:
#             id        price
# 0       193573   892.167419
# 1       193574  2515.858154
# 2       193575  2364.560547
# 3       193576   819.694641
# 4       193577  5723.754883
# ...        ...          ...
# 129045  322618  3785.593506
# 129046  322619  2591.682373
# 129047  322620  7604.695312
# 129048  322621  5411.806641
# 129049  322622  4305.310547
#
# [129050 rows x 2 columns]

# %%
output.to_csv("sample_data/submission.csv", index=False)
